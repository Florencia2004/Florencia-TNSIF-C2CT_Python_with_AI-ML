# %% [markdown]
# <a href="https://colab.research.google.com/github/Florencia2004/Florencia-TNSIF-C2CT_Python_with_AI-ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name:")
age  = int(input("Enter your age:"))

next_age = age +1

print("Hello", name + " you will be", next_age,"years old next year!" )
# Out:
# Enter your name:dora
# Enter your age:15
# Hello dora you will be 16 years old next year!

# %%
number = int(input("Enter a number:"))
number % 2 == 0
if number %2==0:
    print("even")
else :
    print("odd")
# Out:
# Enter a number:4
# even

# %% [markdown]
# # New section

# %%
marks=int(input("enter your marks:"))
if marks>=90:
   print("grade a")
elif marks>=75:
    print("grade b")
elif marks>=50:
    print("grade c")
else:
    print("fail")
# Out:
# enter your marks:67
# grade c

# %%
:""
